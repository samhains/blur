# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from scipy.ndimage import gaussian_filter
from skimage.transform import resize
from skimage import data, io, filters
from libs import utils

# %%
# get_image will return a handle to the image itself, and a numpy array of its pixels to input the network
def get_image(path):
    img = plt.imread(path)
    x = image.img_to_array(img)
    #x = np.expand_dims(x, axis=0)
    #x = preprocess_input(x)
    return img, x

# %%
path = "../data/nolikes"

# %%
img = plt.imread("../data/nolikes/208.jpg")

# %%
imshow(img)

# %%
blurred = filters.gaussian(img, sigma=7, multichannel=True)

# %%
plt.imshow(blurred)

# %%
# You need to find 100 images from the web/create them yourself
# or find a dataset that interests you (e.g. I used celeb faces
# in the course lecture...)
# then store them all in a single directory.
# With all the images in a single directory, you can then
# perform the following steps to create a 4-d array of:
# N x H x W x C dimensions as 100 x 100 x 100 x 3.

dirname = path

# Load every image file in the provided directory
filenames = [os.path.join(dirname, fname)
             for fname in os.listdir(dirname) if fname.endswith('.jpg')]

# Make sure we have exactly 100 image files!
filenames = filenames[:100]
assert(len(filenames) == 100)

# %%
# Read every filename as an RGB image
clean_imgs = [plt.imread(fname) for fname in filenames]

# Finally make our list of 3-D images a 4-D array with the first dimension the number of images:
#imgs = np.array(imgs).astype(np.float32)

# %%
#GAUSSIAN APPROACH

gaussian_imgs = [filters.gaussian(img_i, sigma=7, multichannel=True) for img_i in clean_imgs]

# %%
# RESIZE APPROACH

# Then resize the square image to 100 x 100 pixels
resize_imgs = [resize(img_i, (25, 25)) for img_i in clean_imgs]
resize_imgs = [resize(img_i, (200, 200)) for img_i in resize_imgs]

# %%
plt.imshow(resize_imgs[18])
plt.figure()
#plt.imshow(gaussian_imgs[0])
plt.imshow(clean_imgs[18])

# %%
for fname in filenames:
    img = plt.imread(fname)
    fname = 'blurred_'+fname.split('/')[-1]
    resize_img = resize(img, (25, 25))
    resize_img = resize(resize_img, (200, 200))
    plt.imsave(fname, arr=resize_img)

# %%
'blurred_'+filenames[1].split('/')[-1]
# Out:
# 'blurred_100.jpg'
